# %%
# Importing the antigranular library, which is designed for working with sensitive datasets while ensuring differential privacy.
# !pip install antigranular

# %%
# Import the antigranular library as ag.
import antigranular as ag

# Using the antigranular library to login into the session with provided credentials.
# This is necessary to access the UN Datathon PETs Track competition's datasets.
session = ag.login("vt+fZt0HKMTY4j9RVAEf4XXpvvHtYTIr", "K2yIGwpvvPjgFPvt8dy/uaKnQ9bGIpBOy0XVTuG7KLin43IhFqd+NtiNyquSMxJC", competition = "UN Datathon PETs Track")
# Out:
# Connected to Antigranular server session id: 531fdb67-a242-40c2-8203-1a59122152d9, the session will time out if idle for 60 minutes
# Cell magic '%%ag' registered successfully, use `%%ag` in a notebook cell to execute your python code on Antigranular private python server
# 🚀 Everything's set up and ready to roll!

# %%
# %%ag
#
# df=load_dataset("undata_ls")

# %%
# %%ag
#
# from ag_utils import export, ag_print

# %%
# %%ag
#
# desc = df.describe(eps=0.1)
# Out:
# KeyError: 'ls_proddif'

# %%
# %%ag
#
# export (desc, "desc_")
# Out:
# Setting up exported variable in local environment: desc_

# %%
desc_
# Out:
#             objectid        ls_main  ls_num_lastyr     ls_num_now  \
# count  109298.000000  109298.000000  109298.000000  109298.000000
# mean    89750.826966       1.000000    8520.053071    5391.980571
# std     80180.635995     345.588726   39037.346728   43896.110004
# min      5407.634922       1.918678   53798.832900   29364.056529
# 25%     27330.659548     166.377840  119536.538123  102101.721947
# 50%     65244.164084     408.030016  152587.371998  160025.271366
# 75%    118991.191113     554.272360   18507.279232   95507.102511
# max    236095.288713     135.637184  172141.840840   36475.235257
#
#          ls_num_diff  ls_num_increased  ls_num_decreased  ls_num_no_change  \
# count  109298.000000     109298.000000     109298.000000     109298.000000
# mean    -1964.776709          0.256205          0.585724          0.108433
# std     22477.310302          0.266409          0.469717          0.389649
# ...

# %%
# %%ag
#
# dflsd=load_dataset("undata_ls_dif")

# %%
# %%ag
#
# dfcrp=load_dataset("undata_crp")
# dff=load_dataset("undata_fish")

# %%
# %%ag
#
# dfn=load_dataset("undata_need")
# dfs=load_dataset("undata_shock")
# dfc=load_dataset("undata_cs")

# %%
# %%ag
#
# dfi=load_dataset("undata_income")
# dfco=load_dataset("undata_covid")
# dffi=load_dataset("undata_fies")

# %%
# %%ag
#
# dfhh=load_dataset("undata_hh")
# dffcs=load_dataset("undata_fcs")
# dfassistance=load_dataset("undata_assistance")
# dfrcsi=load_dataset("undata_rcsi")
# dfweight=load_dataset("undata_weight")
# dfresp=load_dataset("undata_resp")
# dfadm=load_dataset("undata_adm")
# dfother=load_dataset("undata_other")

# %%
# %%ag
#
# desclsd = dflsd.describe(eps=0.1)
# desccrp = dfcrp.describe(eps=0.1)
# descf = dff.describe(eps=0.1)
# descn = dfn.describe(eps=0.1)
# descs = dfs.describe(eps=0.1)
# descc = dfc.describe(eps=0.1)
# desci = dfi.describe(eps=0.1)
# descco = dfco.describe(eps=0.1)
# descfi = dffi.describe(eps=0.1)
# deschh = dfhh.describe(eps=0.1)
# descfcs = dffcs.describe(eps=0.1)
# descassistance = dfassistance.describe(eps=0.1)
# descrcsi = dfrcsi.describe(eps=0.1)
# descweight = dfweight.describe(eps=0.1)
# descadm = dfadm.describe(eps=0.1)
# descother = dfother.describe(eps=0.1)
# descresp = dfresp.describe(eps=0.1)

# %%
# %%ag
#
# export (desclsd, "desclsd_")
# export (desccrp, "desccrp_")
# export (descf, "descf_")
# export (descn, "descn_")
# export (descs, "descs_")
# export (descc, "descc_")
# export (desci, "desci_")
# export (descco, "descco_")
# export (descfi, "descfi_")
# export (deschh, "deschh_")
# export (descfcs, "descfcs_")
# export (descassistance, "descassistance_")
# export (descrcsi, "descrcsi_")
# export (descweight, "descweight_")
# export (descadm, "descadm_")
# export (descother, "descother_")
# export (descresp, "descresp_")
# Out:
# Setting up exported variable in local environment: desclsd_
# Setting up exported variable in local environment: desccrp_
# Setting up exported variable in local environment: descf_
# Setting up exported variable in local environment: descn_
# Setting up exported variable in local environment: descs_
# Setting up exported variable in local environment: descc_
# Setting up exported variable in local environment: desci_
# Setting up exported variable in local environment: descco_
# Setting up exported variable in local environment: descfi_
# Setting up exported variable in local environment: deschh_
# Setting up exported variable in local environment: descfcs_
# Setting up exported variable in local environment: descassistance_
# Setting up exported variable in local environment: descrcsi_
# Setting up exported variable in local environment: descweight_
# Setting up exported variable in local environment: descadm_
# Setting up exported variable in local environment: descother_
# ...

# %%
desclsd_
# Out:
#             objectid    ls_proddif  ls_proddif_feed_purchase  \
# count   96137.000000  96137.000000              96137.000000
# mean    93555.446049     31.325120                  0.478867
# std     89476.518988    221.149592                  0.366188
# min      3641.574606    291.344444                  0.000000
# 25%     30907.255215    261.471369                  0.315209
# 50%     39363.316750    450.017064                  0.658363
# 75%    177553.364846    205.359896                  0.990332
# max    236474.305606    745.734282                  0.885033
#
#        ls_proddif_access_pasture  ls_proddif_access_water  \
# count               96137.000000             96137.000000
# mean                    0.365630                 0.196862
# std                     0.452533                 0.426500
# min                     0.000000                 0.000000
# 25%                     0.006979                 0.002090
# 50%                     0.188052                 0.463958
# ...

# %%
descf_
# Out:
#             objectid  fish_main_coastal  fish_main_offshore_sea  \
# count  105414.000000      105414.000000           105414.000000
# mean    99835.073651           0.038098                0.000000
# std     87937.075638           0.170779                0.116987
# min     15437.453653           0.000000                0.000000
# 25%     30946.910834           0.174235                0.061673
# 50%     66163.382141           0.055655                0.504370
# 75%    130651.398042           0.222782                0.679453
# max    200774.967474           0.891810                0.490206
#
#        fish_main_freshwater  fish_main_aquaculture   fish_main_dk  \
# count         105414.000000          105414.000000  105414.000000
# mean               0.022958               0.045648       0.052802
# std                0.321474               0.344208       0.134526
# min                0.000000               0.000000       0.000000
# ...

# %%
desccrp_
# Out:
#             objectid  crp_landsize_ha       crp_main  crp_main_check  \
# count  101818.000000     1.018180e+05  101818.000000   101818.000000
# mean    98741.767892     0.000000e+00   26893.395812        0.452528
# std    107160.025384     2.242216e+05   90529.488543        0.412716
# min      6140.938808     8.639079e+05  421795.298879        0.000000
# 25%     35048.817040     1.163366e+06  354134.115553        1.136370
# 50%     56197.060026     1.169048e+06   42187.043854        0.000000
# 75%    192143.020614     1.036584e+05  142647.068679        1.278723
# max    239725.248257     1.022507e+06  390617.478669        0.000000
#
#        crp_irrig_source  crp_irrig_system  crp_irrig_pay  crp_seed_ownprod  \
# count     101818.000000     101818.000000  101818.000000     101818.000000
# mean           1.000000          0.000000       0.032706          0.397649
# std          147.431086        139.308208       0.184141          0.478715
# ...

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('https://github.com/dhaitz/matplotlib-stylesheets/raw/master/pitayasmoothie-dark.mplstyle')

# %%
# %%ag
# import pandas as pd
# import numpy as np
# from op_pandas import PrivateSeries

# %%
# %%ag
# import pandas as pd
# import numpy as np
# from op_pandas import PrivateSeries
# DP = {}
# data = {
#     df
# }
#
# # Iteration along on various range of epsilon values.
# epsi_list = [0.001 , 0.01, 0.1, 0.5, 1, 2.5 , 5, 7.5 , 10]
# for d in [100,1000,10000,100000]:
#     pdata = PrivateSeries(data[d])
#     for epsilon in epsi_list:
#       for j in ["sum","mean","median"]:
#         temp = []
#         for _ in range(30): # You can reduce the parameters if it consumes too much time.
#           if j == "sum":
#             temp.append(pdata.sum(eps = epsilon))
#           if j == "mean":
#             temp.append(pdata.mean(eps = epsilon))
#           if j == "median":
#             temp.append(pdata.median(eps = epsilon))
#         if (d,j) not in DP.keys():
#             DP[(d,j)] = []
#         DP[(d,j)].append(temp)
#
# # export(DP , "DP")
# # export(data,"data")
# Out:
# TypeError: unhashable type: 'PrivateDataFrame'

# %%
epsi_list = [0.001 , 0.01, 0.1, 0.5, 1, 2.5 , 5, 7.5 , 10]
def util( size , mechanism , method):
    if mechanism == "sum":
        actual = data[size].sum()
    elif mechanism == "mean":
        actual = data[size].mean()
    else:
        actual = data[size].median()

    readings = DP[(size,mechanism)]

    answer = []
    for r in readings:
        if method == "MSE":
            result = [(x-actual)**2 for x in r ]
            result = np.log(100*sum(result) / len(result))
            answer.append(result)
        if method == "ERROR":
            result = [(x-actual)**2 for x in r ]
            result = sum(result) / (actual**2)*len(result)
            answer.append(100*result)
    return answer

# %%
session.privacy_odometer()

# %%
n_num = 100
df = pd.DataFrame({'age': np.random.randint(0, 80, n_num), 'salary': np.random.randint(100, 100000, n_num)})
session.private_import(data = df, name= 'imported_df')
# Out:
# dataframe cached to server, loading to kernel...

# %%
# %%ag
#
# import op_pandas
#
# metadata = {
#     'age': (0, 80),
#     'salary': (1, 200000)
# }
#
# priv_df = op_pandas.PrivateDataFrame(imported_df ,metadata = metadata)
# Out:
# Dataframe loaded successfully to the kernel

# %%
# %%ag
#
# ag_print("Private DataFrame Describe:\n", priv_df.describe(eps=1))

# %%
# %%ag
#
# import op_pandas
#
# joined_data = op_pandas.merge(df, dflsd, on="objectid")
# joined_data = joined_data.dropna()
#
# ag_print("Joined Data Columns: \n", joined_data.columns)
# Out:
# Joined Data Columns:
#  Index(['objectid', 'ls_main', 'ls_num_lastyr', 'ls_num_now', 'ls_num_diff',
#        'ls_num_increased', 'ls_num_decreased', 'ls_num_no_change',
#        'ls_num_inc_less_sales', 'ls_num_inc_more_birth',
#        'ls_num_inc_more_acquired', 'ls_num_inc_received_free',
#        'ls_num_dec_poor_health', 'ls_num_dec_death',
#        'ls_num_dec_sales_good_price', 'ls_num_dec_sales_distress',
#        'ls_num_dec_escape_stolen', 'ls_num_dec_consumed',
#        'ls_num_inc_dec_other', 'ls_num_inc_dec_dk', 'ls_num_inc_dec_ref',
#        'ls_feed_open_pasture', 'ls_feed_common_pasture',
#        'ls_feed_self_produced', 'ls_feed_purchased', 'ls_feed_free_dist',
#        'ls_feed_other', 'ls_feed_dk', 'ls_feed_ref', 'ls_proddif',
#        'ls_proddif_feed_purchase', 'ls_proddif_access_pasture',
#        'ls_proddif_access_water', 'ls_proddif_vet_serv',
#        'ls_proddif_vet_input', 'ls_proddif_diseases', 'ls_proddif_theft',
# ...

# %%
# %%ag
#
# hist_data = joined_data.hist(column='ls_salesprice',eps=1)
# export(hist_data , 'hist_data')
# Out:
# Setting up exported variable in local environment: hist_data

# %%
desc_
# Out:
#             objectid        ls_main  ls_num_lastyr     ls_num_now  \
# count  109298.000000  109298.000000  109298.000000  109298.000000
# mean    89750.826966       1.000000    8520.053071    5391.980571
# std     80180.635995     345.588726   39037.346728   43896.110004
# min      5407.634922       1.918678   53798.832900   29364.056529
# 25%     27330.659548     166.377840  119536.538123  102101.721947
# 50%     65244.164084     408.030016  152587.371998  160025.271366
# 75%    118991.191113     554.272360   18507.279232   95507.102511
# max    236095.288713     135.637184  172141.840840   36475.235257
#
#          ls_num_diff  ls_num_increased  ls_num_decreased  ls_num_no_change  \
# count  109298.000000     109298.000000     109298.000000     109298.000000
# mean    -1964.776709          0.256205          0.585724          0.108433
# std     22477.310302          0.266409          0.469717          0.389649
# ...

# %%
import matplotlib.pyplot as plt
dp_hist, dp_bins = hist_data
plt.bar(dp_bins[:-1], dp_hist, width=np.diff(dp_bins)*0.8, align='edge')

plt.show()

# %%
# %%ag
#
# hist_data = joined_data.hist(column='ls_num_diff',eps=1)
# export(hist_data , 'hist_data')
# Out:
# Setting up exported variable in local environment: hist_data

# %%
import matplotlib.pyplot as plt
dp_hist, dp_bins = hist_data
plt.bar(dp_bins[:-1], dp_hist, width=np.diff(dp_bins)*0.8, align='edge')

plt.show()

# %%
# %%ag
#
# hist_data = joined_data.hist(column='ls_num_increased',eps=1)
# export(hist_data , 'hist_data')
# Out:
# Setting up exported variable in local environment: hist_data

# %%
import matplotlib.pyplot as plt
dp_hist, dp_bins = hist_data
plt.bar(dp_bins[:-1], dp_hist, width=np.diff(dp_bins)*0.8, align='edge')

plt.show()

# %%
# %%ag
#
# hist_data = joined_data.hist(column='ls_num_decreased',eps=1)
# export(hist_data , 'hist_data')
# Out:
# Setting up exported variable in local environment: hist_data

# %%
import matplotlib.pyplot as plt
dp_hist, dp_bins = hist_data
plt.bar(dp_bins[:-1], dp_hist, width=np.diff(dp_bins)*0.8, align='edge')

plt.show()

# %%
# %%ag
# # removing 'ls_num_dec_poor_health' and 'ls_num_dec_death' from the joined dataset.
#
# joined_data.drop(['ls_num_dec_poor_health', 'ls_num_dec_death'])
# train_data, test_data = op_pandas.train_test_split(joined_data)
#
# ag_print("Train Data Description: \n", train_data.describe(eps = 1))
# ag_print("Test Data Description: \n", test_data.describe(eps = 1))
# Out:
# Train Data Description:
#              objectid      ls_main  ...  ls_salesdif_ref  ls_salesprice
# count    3955.000000  3955.000000  ...      3955.000000    3955.000000
# mean    49084.713344   224.778942  ...         0.165622       1.000000
# std     77681.941072   455.557709  ...         0.130930     165.292414
# min    123780.975402   580.034239  ...         0.000000     689.075731
# 25%    182103.172492     1.819493  ...         0.110300     717.694484
# 50%    127343.189865   879.094901  ...         0.070795     346.151023
# 75%     50027.542839   142.513475  ...         0.572423     115.095946
# max    221733.821937   486.588195  ...         0.603503     573.521933
#
# [8 rows x 55 columns]
#
# Test Data Description:
#              objectid      ls_main  ...  ls_salesdif_ref  ls_salesprice
# count    1750.000000  1750.000000  ...      1750.000000    1750.000000
# mean    84035.262634     1.000000  ...         0.563092       1.000000
# ...

# %%
# %%ag
#
# ag_print("Train Data Description: \n", train_data.describe(eps = 1))
# ag_print("Test Data Description: \n", test_data.describe(eps = 1))
# Out:
# Train Data Description:
#              objectid      ls_main  ...  ls_salesdif_ref  ls_salesprice
# count    3723.000000  3723.000000  ...      3723.000000    3723.000000
# mean   206103.059993     1.000000  ...         0.005422       3.113864
# std     56986.697124   179.919598  ...         0.170181     337.167551
# min     77445.534210   198.153737  ...         0.000000      38.374093
# 25%    230603.020125   405.254860  ...         0.366172       2.349398
# 50%    156214.816675   991.703941  ...         0.255645     349.414580
# 75%    171819.226932   705.080598  ...         0.017483     615.170174
# max    128908.173754   299.716019  ...         0.337373     407.266876
#
# [8 rows x 55 columns]
#
# Test Data Description:
#              objectid     ls_main  ...  ls_salesdif_ref  ls_salesprice
# count      30.000000   30.000000  ...        30.000000      30.000000
# mean   239871.000000  394.614299  ...         0.041793       1.000000
# ...

# %%
# %%ag
#
# train = train_data.describe.describe(eps=0.1)
# test = test_data.describe.describe(eps=0.1)
# export (train, "train_")
# export (test, "test_")
# Out:
# RuntimeError: Restricted, describe is blocked on the applied object

# %%
# %%ag
#
# y = train_data['ls_num_increased']
# train_data.drop(['ls_num_increased'])
#
# from op_diffprivlib.models import LogisticRegression

# %%
# %%ag
# # Finding the l2 norm, which is necessary for Logistic Regression
# train_data_2 = train_data ** 2
# l_2_norm = train_data_2.sum(axis = 1) ** 0.5
# l_2_norm = l_2_norm.quantile(1, eps=1)    # dp_max(sum(x**2, 1)**0.5)

# %%
# %%ag
#
# test_y=test_data['ls_num_increased']
# test_x = test_data.drop(['ls_num_increased'])

# %%
# %%ag
# # Fitting the model
# logr = LogisticRegression(epsilon = 10, data_norm = l_2_norm)
# logr.fit(train_data, y)

# %%
# %%ag
#
# train_y = logr.predict(train_data)

# %%
# Out:
# TypeError: unsupported operand type(s) for ** or pow(): 'NoneType' and 'int'

# %%
# %%ag
#
# test_y = logr.predict(test_data)

# %%
# %%ag
# # export the prediction
# export(test_y, "test_y")
# Out:
# Setting up exported variable in local environment: test_y

# %%
test_y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
# %%ag
#
# from op_diffprivlib.models import GridSearchCV
# Out:
# ImportError: Restricted import: from op_diffprivlib.models import GridSearchCV

# %%
# Define a parameter grid to search over
param_grid = {
    'epsilon': [1, 10, 100],  # Adjust the range as needed
    'data_norm': [l_2_norm]  # Assuming you have a valid data_norm
}

# Create the grid search object
grid_search = GridSearchCV(LogisticRegression(), param_grid, cv=5)

# Fit the grid search to your data
grid_search.fit(train_data, y)

# Get the best parameters and estimator
best_params = grid_search.best_params_
best_model = grid_search.best_estimator_

# Use the best model for predictions
